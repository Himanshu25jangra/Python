# %% [markdown]
# 1. Create
#
#     1.Enter Name
#     2. Enter Age (18-60)
#     3. Enteryour Designation (p25/M30/T20) y/n
#
# 2.Display
#     Name age salary Designation
#
# 3. Raise
#     Enter name of employee
#     How much Raise(1-30%)
#
# 4. Exit
#     Thank you

# %%
class Emp():
    def create(self):
        name= input("Enter your name")
        age = input("Enter your age")
        desg= input(designation())
        salary = input("Enter your salary")
        
    def designation(self):
        print("Choose designation\n 1.P25 2.M30 3.T20\n")
