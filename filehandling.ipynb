# %%
f= open('File.docx', 'w')
f.write('This is a test file.\n')
f.write('This file is created to test the file writing functionality.\n')  
f.close()
print('Writing to file completed successfully.')
# Out:
# Writing to file completed successfully.

# %%
f= open('File.docx', 'r')
print(f.read())
# Out:
# This is a test file.
# This file is created to test the file writing functionality.
