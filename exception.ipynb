# %%
## Task1. Login page (exception handling)
##

# %%
a=10
b=0
try:
    c=a/b   #1st exception
    print(c)
except ZeroDivisionError:
    print("Cant divide")

print("Rest of the code")
# Out:
# Cant divide
# Rest of the code

# %%
a= int(input("Enter first number"))
b= int(input("Enter second number"))
try:
    c=a/b   #1st exception
    print(c)
except ZeroDivisionError:
    print("Cant divide")

print("Rest of the code")
# Out:
# Cant divide
# Rest of the code

# %%
a=10
b=2
try:

    c=a/b  #1st exception
    d=a/g   #2nd exception
    print(c)
except (NameError,ZeroDivisionError) as obj:
    print(obj)

print("Rest of the code")
# Out:
# name 'g' is not defined
# Rest of the code

# %%
class TooyoungException (Exception):
    def __init__(self,arg):
        self.msg=arg
        
class ToooldException (Exception):
    def __init__(self,arg):
        self.msg=arg
        
age = int(input("Enter your age"))
if age>60:
    raise ToooldException("YOur too old")
elif age<18:
    raise TooyoungException("Your still kid")
else:
    print("Prefect")
# Out:
# ---------------------------------------------------------------------------
# ToooldException                           Traceback (most recent call last)
# Cell In[14], line 11
#       9 age = int(input("Enter your age"))
#      10 if age>60:
# ---> 11     raise ToooldException("YOur too old")
#      12 elif age<18:
#      13     raise TooyoungException("Your still kid")
#
# ToooldException: YOur too old

# %%
class TooyoungException ():
    def __init__(self,arg):
        self.msg=arg
        print(self.msg)

x= TooyoungException("Hll")
# Out:
# Hll

# %%
class Login():
    def credential(self):
        self.username = input("Enter your name")
        self.password = input("Enter password")
        
    def check_cred(self):
        name = input("Enter your name")
        passs = input("Enter password")
        try:
            if name==self.username and passs==self.password:
                print("Login Success")
            else:
                raise ValueError("Wrong!!!!")
        
        except ValueError as e:
            print(e)
       
login= Login()
login.credential()
login.check_cred()
# Out:
# Wrong!!!!
